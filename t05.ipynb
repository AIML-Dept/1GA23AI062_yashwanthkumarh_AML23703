# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
import numpy as np

# Create 2-qubit circuit
qc = QuantumCircuit(2)

# Choose a rotation angle
theta = np.pi / 3

# Create a non-equal superposition
qc.ry(theta, 0)

# Entangle the qubits
qc.cx(0, 1)

# Calculate statevector
state = Statevector.from_instruction(qc)

print("Entangled State Circuit:")
print(qc)

print("\nStatevector:")
print(state)

print("\nProbability Distribution:")
print(state.probabilities_dict())
# Out:
# Entangled State Circuit:
#      ┌─────────┐
# q_0: ┤ Ry(π/3) ├──■──
#      └─────────┘┌─┴─┐
# q_1: ───────────┤ X ├
#                 └───┘
#
# Statevector:
# Statevector([0.8660254+0.j, 0.       +0.j, 0.       +0.j, 0.5      +0.j],
#             dims=(2, 2))
#
# Probability Distribution:
# {np.str_('00'): np.float64(0.7500000000000001), np.str_('11'): np.float64(0.24999999999999994)}
